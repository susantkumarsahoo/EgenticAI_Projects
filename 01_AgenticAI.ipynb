# %%
print("Hello World")
# Out:
# Hello World

# %%
# app.py
import os
from dotenv import load_dotenv
from langchain_openai import ChatOpenAI


# ✅ Load environment variables
load_dotenv()

# ✅ Get the OpenAI API key from .env
openai_api_key = os.getenv("OPENAI_API_KEY")

# ✅ Initialize the model
llm = ChatOpenAI(
    model="gpt-3.5-turbo",
    temperature=0.7,
    openai_api_key=openai_api_key
)


# ✅ Chat loop
print("🤖 Simple Chatbot (type 'exit' to stop)\n")

# 🤖 Simple Chatbot (type 'exit' to stop)
while True:
    user_input = input("You: ")
    if user_input.lower() == 'exit':
        print("Chatbot: Goodbye 👋")
        break
    
    # The fix: use 'invoke' instead of 'predict'
    response = llm.invoke(user_input) 
    print(f"Chatbot: {response}")
# Out:
# 🤖 Simple Chatbot (type 'exit' to stop)
#
# Chatbot: content='Hello! How can I assist you today?' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 9, 'prompt_tokens': 9, 'total_tokens': 18, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'id': 'chatcmpl-CXCtxUtZvf1MmInCJ7PDTLrXT9wJa', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None} id='lc_run--89b0cfcf-07da-4b11-b580-51aba0006264-0' usage_metadata={'input_tokens': 9, 'output_tokens': 9, 'total_tokens': 18, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}
# Chatbot: content='A data scientist is a professional who is responsible for collecting, analyzing, and interpreting large amounts of complex data to help organizations make informed decisions. They use a combination of statistical analysis, machine learning, and programming skills to uncover insights and trends in data that can be used to drive business strategy and decision-making. Data scientists work across a variety of industries, including technology, finance, healthcare, and marketing.' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 80, 'prompt_tokens': 13, 'total_tokens': 93, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'id': 'chatcmpl-CXCujEw0Qu6ILdTTQakY9kHkdCvge', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None} id='lc_run--e4d2185b-fda1-4901-8c94-4a6bcf712d5e-0' usage_metadata={'input_tokens': 13, 'output_tokens': 80, 'total_tokens': 93, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}
# Chatbot: Goodbye 👋
